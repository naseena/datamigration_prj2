# %%
import pandas as pd
from pandas import read_excel

# %%
p_druglist=pd.read_excel(r"C:\Users\hp\Downloads\patients _and _druglist.xlsx")

# %%
p_druglist
# Out:
#    NDC-NBR DRUG-LIST-ID FEATURE-USE
# 0    P_100          DR1  2025-31-12
# 1    P_100          DR2  2025-31-12
# 2    P_100          DR3  2025-31-12
# 3    P_100          DR4  2025-31-12
# 4    P_100          DR5  2025-31-12
# 5    P_101          DR1  2025-31-12
# 6    p_101          DR2  2025-31-12
# 7    p_101          DR3  2025-31-12
# 8    p_101          DR4  2025-31-12
# 9    p_102          DR1  2025-31-12
# 10   p_102          DR5  2025-31-12
# 11   p_102          DR3  2025-31-12
# 12   p_102          DR2  2025-31-12
# 13   p_103          DR1  2025-31-12
# 14   p_103          DR5  2025-31-12
# 15   p_103          DR2  2025-31-12
# 16   p_103          DR4  2025-31-12
# 17   p_104          DR3  2025-31-12
# 18   p_104          DR1  2025-31-12
# 19   p_104          DR2  2025-31-12
# 20   p_104          DR4  2025-31-12
# 21   p_105          DR3  2025-31-12
# 22   p_105          DR1  2025-31-12
# 23   p_105          DR5  2025-31-12
# 24   p_105          DR2  2025-31-12
# ...

# %%
p_druglist.head()
# Out:
#   NDC-NBR DRUG-LIST-ID FEATURE-USE
# 0   P_100          DR1  2025-31-12
# 1   P_100          DR2  2025-31-12
# 2   P_100          DR3  2025-31-12
# 3   P_100          DR4  2025-31-12
# 4   P_100          DR5  2025-31-12

# %%
p_druglist.columns
# Out:
# Index(['NDC-NBR', 'DRUG-LIST-ID', 'FEATURE-USE'], dtype='object')

# %%
p_druglist.tail()
# Out:
#    NDC-NBR DRUG-LIST-ID FEATURE-USE
# 40   p_109          DR3  2025-31-12
# 41   p_110          DR2  2025-31-12
# 42   p_110          DR4  2025-31-12
# 43   p-110          DR1  2025-31-12
# 44   p_110          DR3  2025-31-12

# %%
p_druglist.shape
# Out:
# (45, 3)

# %%
IW_MBRENG_WORKDB_NDC_DCR_LIST=pd.DataFrame()

# %%
IW_MBRENG_WORKDB_NDC_DCR_LIST['DCR_NDC_NBR']=" "

# %%
IW_MBRENG_WORKDB_NDC_DCR_LIST['DCR_DRUG_LIST_ID']=" "

# %%
IW_MBRENG_WORKDB_NDC_DCR_LIST.columns
# Out:
# Index(['DCR_NDC_NBR', 'DCR_DRUG_LIST_ID'], dtype='object')
